# %% [markdown]
# # dbt execution notebook
#
# This notebook is responsible for **executing dbt commands inside Microsoft Fabric** while providing:
#
# - **Live streaming of dbt logs** to the notebook output
# - **Centralized log persistence** to a Lakehouse location
# - **Run-level metadata tracking** (run id, environment, branch, workspace)
# - **Fail-fast behavior** to ensure pipeline correctness
#
# The goal of this notebook is to make dbt runs:
# - **Observable** – logs are visible in real time
# - **Auditable** – complete logs are stored centrally
# - **Deterministic** – failures reliably stop downstream execution
#
# ---
#
# ## What this notebook does
#
# 1. Builds the dbt command dynamically based on:
#    - Selected models / selectors
#    - Environment (OTAP stage)
#    - Active Git branch
# 2. Executes dbt using a subprocess with **streamed stdout/stderr**
# 3. Captures all dbt output into an in-memory log buffer
# 4. Writes a consolidated run log to the Lakehouse after execution
# 5. Fails the notebook when dbt exits with a non-zero status
#
# ---
#
# ## Logging strategy
#
# - **Live output**
#   All dbt output is streamed line-by-line to the notebook for immediate visibility.
#
# - **Persistent logs**
#   The full dbt output is written to a timestamped log file in the Lakehouse, including:
#   - Run metadata
#   - Environment context
#   - Full raw dbt output
#
# This ensures logs remain available for:
# - Debugging failed runs
# - Post-run analysis
# - Compliance and auditing
#
# ---
#
# ## Expected usage
#
# This notebook is intended to be:
# - Triggered from **pipelines** (ADO / Fabric / CI/CD)
# - Parameterized per environment and workspace
# - Used as a **single execution point** for dbt within Fabric
#
# Do **not** use this notebook for:
# - Interactive model development
# - Local debugging of dbt projects
#
# ---
#
# ## Failure behavior
#
# If dbt fails:
# - The failure is immediately visible in the notebook output
# - The complete log is still written to the Lakehouse
# - The notebook raises an exception to stop downstream execution
#
# This behavior is intentional to guarantee data quality.
#
# ---

# %% [markdown]
# ## 1. Parameters

# %%
# passed parameters from pipeline
run_id = "n/a" # pipeline run id

# %%
# constants
zip_src = '/lakehouse/default/Files/dbt-repo-zips' # local shortcut to central repo lakehouse folder
dbt_authentication = 'ActiveDirectoryAccessToken'  #https://docs.getdbt.com/docs/cloud/connect-data-platform/connect-microsoft-fabric
# get workspace config in varlib 'v_dbt_runner'
v_dbt_runner = notebookutils.variableLibrary.getLibrary("v_dbt_runner")

#folders 
run_dir = f"/tmp/dbt_project"
lakehouse_log_dir = f"/lakehouse/default/Files/logs"

# %%
# workspace config parameters
ws_name = v_dbt_runner.workspace_name # current ws
stage = v_dbt_runner.stage                                       # type
git_branch = v_dbt_runner.git_branch   

# dbt config parameters
dbt_command = v_dbt_runner.dbt_command 
dbt_selector = v_dbt_runner.dbt_selector           # project scope to run
target_connection_string = v_dbt_runner.target_connection_string 
target_database = v_dbt_runner.target_database

# %% [markdown]
# ## 2. class dbtrunner

# %%
from datetime import datetime
import subprocess, shlex

class DbtRunner:
    def __init__(self, lakehouse_log_path: str, flush_every: int = 25):
        self.lakehouse_log_path = lakehouse_log_path
        self.flush_every = flush_every
        self.buffer = []
        self.persisted_log = ""   # <-- NEW
        self.success = True
        self.failure_type = None
        self.start_time = None

    # ---------- logging ----------
    def log(self, message: str, level: str = "INFO", end: str = "\n"):
        timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        formatted = f"[{timestamp}] [{level}] {message}"

        print(formatted, end=end)
        self.buffer.append(f"{formatted}{end}")

        if len(self.buffer) >= self.flush_every:
            self.flush()

    def flush(self):
        if not self.buffer:
            return

        try:
            chunk = "".join(self.buffer)
            self.buffer.clear()

            self.persisted_log += chunk

            notebookutils.fs.put(
                self.lakehouse_log_path,
                self.persisted_log,
                overwrite=True
            )

        except Exception as e:
            print(f"[WARN] Failed to flush logs: {e}")

    # ---------- dbt failure classification ----------
    def classify_failure(self, line: str):
        if "Compilation Error" in line:
            return "COMPILATION"
        if "Database Error" in line:
            return "DATABASE"
        if "Runtime Error" in line:
            return "RUNTIME"
        if "FAIL" in line:
            return "TEST_FAILURE"
        return None

    # ---------- execution ----------
    def run(self, cmd: str):
        self.start_time = datetime.now()
        self.log("Starting dbt run")

        process = subprocess.Popen(
            shlex.split(cmd),
            stdout=subprocess.PIPE,
            stderr=subprocess.STDOUT,
            text=True,
            bufsize=1
        )

        for line in process.stdout:
            self.log(line, end="")

            if not self.failure_type:
                failure = self.classify_failure(line)
                if failure:
                    self.failure_type = failure

        return_code = process.wait()
        if return_code != 0:
            self.success = False
            self.log(
                f"dbt exited with return code {return_code}",
                level="ERROR"
            )

        self.flush()
        self.finish()        

        if not self.success:
            raise RuntimeError("dbt run failed")

    # ---------- finish ----------
    def finish(self):
        duration = (datetime.now() - self.start_time).total_seconds()

        self.log("")
        self.log("=" * 40)
        self.log("DBT Run Finished")
        self.log(f"Success: {self.success}")
        self.log(f"Duration: {duration:.1f}s")

        if self.failure_type:
            self.log(f"Failure type: {self.failure_type}", level="ERROR")

        self.log("=" * 40)

        self.flush()

# %% [markdown]
# ## 3. Init

# %%
# import packages

import json
import subprocess
import logging
import os
import re
from datetime import datetime
from sempy import fabric
import zipfile
import shutil
import shlex
import notebookutils

# install dbt-fabric
# %pip install dbt-fabric[PyHive]
# Out:
# Requirement already satisfied: dbt-fabric[PyHive] in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (1.9.8)
# WARNING: dbt-fabric 1.9.8 does not provide the extra 'pyhive'
# Requirement already satisfied: pyodbc>=5.2.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from dbt-fabric[PyHive]) (5.3.0)
# Requirement already satisfied: azure-identity>=1.14.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from dbt-fabric[PyHive]) (1.17.1)
# Requirement already satisfied: azure-core>=1.26.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from dbt-fabric[PyHive]) (1.29.4)
# Requirement already satisfied: dbt-common<2.0,>=1.0.4 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from dbt-fabric[PyHive]) (1.37.2)
# Requirement already satisfied: dbt-core>=1.8.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from dbt-fabric[PyHive]) (1.10.15)
# Requirement already satisfied: dbt-adapters<2.0,>=1.1.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from dbt-fabric[PyHive]) (1.22.0)
# Requirement already satisfied: requests>=2.18.4 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from azure-core>=1.26.0->dbt-fabric[PyHive]) (2.32.5)
# Requirement already satisfied: six>=1.11.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from azure-core>=1.26.0->dbt-fabric[PyHive]) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from azure-core>=1.26.0->dbt-fabric[PyHive]) (4.15.0)
# Requirement already satisfied: cryptography>=2.5 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from azure-identity>=1.14.0->dbt-fabric[PyHive]) (45.0.6)
# Requirement already satisfied: msal>=1.24.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from azure-identity>=1.14.0->dbt-fabric[PyHive]) (1.33.0)
# Requirement already satisfied: msal-extensions>=0.3.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from azure-identity>=1.14.0->dbt-fabric[PyHive]) (1.3.1)
# Requirement already satisfied: agate<2.0,>=1.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from dbt-adapters<2.0,>=1.1.1->dbt-fabric[PyHive]) (1.9.1)
# Requirement already satisfied: dbt-protos<2.0,>=1.0.291 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from dbt-adapters<2.0,>=1.1.1->dbt-fabric[PyHive]) (1.0.410)
# Requirement already satisfied: mashumaro<3.15,>=3.9 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from mashumaro[msgpack]<3.15,>=3.9->dbt-adapters<2.0,>=1.1.1->dbt-fabric[PyHive]) (3.14)
# Requirement already satisfied: protobuf<7.0,>=6.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from dbt-adapters<2.0,>=1.1.1->dbt-fabric[PyHive]) (6.33.2)
# Requirement already satisfied: pytz>=2015.7 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from dbt-adapters<2.0,>=1.1.1->dbt-fabric[PyHive]) (2025.2)
# Requirement already satisfied: colorama<0.5,>=0.3.9 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from dbt-common<2.0,>=1.0.4->dbt-fabric[PyHive]) (0.4.6)
# Requirement already satisfied: deepdiff<9.0,>=7.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from dbt-common<2.0,>=1.0.4->dbt-fabric[PyHive]) (8.6.1)
# Requirement already satisfied: isodate<0.8,>=0.6 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from dbt-common<2.0,>=1.0.4->dbt-fabric[PyHive]) (0.6.1)
# Requirement already satisfied: jinja2<4,>=3.1.3 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from dbt-common<2.0,>=1.0.4->dbt-fabric[PyHive]) (3.1.6)
# Requirement already satisfied: jsonschema<5.0,>=4.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from dbt-common<2.0,>=1.0.4->dbt-fabric[PyHive]) (4.25.1)
# Requirement already satisfied: pathspec<0.13,>=0.9 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from dbt-common<2.0,>=1.0.4->dbt-fabric[PyHive]) (0.12.1)
# Requirement already satisfied: python-dateutil<3.0,>=2.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from dbt-common<2.0,>=1.0.4->dbt-fabric[PyHive]) (2.9.0.post0)
# Requirement already satisfied: click<9.0,>=8.0.2 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from dbt-core>=1.8.0->dbt-fabric[PyHive]) (8.2.1)
# Requirement already satisfied: networkx<4.0,>=2.3 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from dbt-core>=1.8.0->dbt-fabric[PyHive]) (3.5)
# Requirement already satisfied: snowplow-tracker<2.0,>=1.0.2 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from dbt-core>=1.8.0->dbt-fabric[PyHive]) (1.1.0)
# Requirement already satisfied: sqlparse<0.6.0,>=0.5.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from dbt-core>=1.8.0->dbt-fabric[PyHive]) (0.5.3)
# Requirement already satisfied: dbt-extractor<=0.6,>=0.5.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from dbt-core>=1.8.0->dbt-fabric[PyHive]) (0.6.0)
# Requirement already satisfied: dbt-semantic-interfaces<0.10,>=0.9.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from dbt-core>=1.8.0->dbt-fabric[PyHive]) (0.9.0)
# Requirement already satisfied: pydantic<3 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from dbt-core>=1.8.0->dbt-fabric[PyHive]) (2.11.7)
# Requirement already satisfied: packaging>20.9 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from dbt-core>=1.8.0->dbt-fabric[PyHive]) (24.2)
# Requirement already satisfied: pyyaml>=6.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from dbt-core>=1.8.0->dbt-fabric[PyHive]) (6.0.2)
# Requirement already satisfied: daff>=1.3.46 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from dbt-core>=1.8.0->dbt-fabric[PyHive]) (1.4.2)
# Requirement already satisfied: Babel>=2.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from agate<2.0,>=1.0->dbt-adapters<2.0,>=1.1.1->dbt-fabric[PyHive]) (2.17.0)
# Requirement already satisfied: leather>=0.3.2 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from agate<2.0,>=1.0->dbt-adapters<2.0,>=1.1.1->dbt-fabric[PyHive]) (0.4.1)
# Requirement already satisfied: parsedatetime!=2.5,>=2.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from agate<2.0,>=1.0->dbt-adapters<2.0,>=1.1.1->dbt-fabric[PyHive]) (2.6)
# Requirement already satisfied: python-slugify>=1.2.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from agate<2.0,>=1.0->dbt-adapters<2.0,>=1.1.1->dbt-fabric[PyHive]) (8.0.4)
# Requirement already satisfied: pytimeparse>=1.1.5 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from agate<2.0,>=1.0->dbt-adapters<2.0,>=1.1.1->dbt-fabric[PyHive]) (1.1.8)
# Requirement already satisfied: cffi>=1.14 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from cryptography>=2.5->azure-identity>=1.14.0->dbt-fabric[PyHive]) (1.17.1)
# Requirement already satisfied: importlib-metadata<9,>=6.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from dbt-semantic-interfaces<0.10,>=0.9.0->dbt-core>=1.8.0->dbt-fabric[PyHive]) (7.0.2)
# Requirement already satisfied: more-itertools<11.0,>=8.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from dbt-semantic-interfaces<0.10,>=0.9.0->dbt-core>=1.8.0->dbt-fabric[PyHive]) (10.8.0)
# Requirement already satisfied: orderly-set<6,>=5.4.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from deepdiff<9.0,>=7.0->dbt-common<2.0,>=1.0.4->dbt-fabric[PyHive]) (5.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from jinja2<4,>=3.1.3->dbt-common<2.0,>=1.0.4->dbt-fabric[PyHive]) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.0.4->dbt-fabric[PyHive]) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.0.4->dbt-fabric[PyHive]) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.0.4->dbt-fabric[PyHive]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.0.4->dbt-fabric[PyHive]) (0.27.1)
# Requirement already satisfied: msgpack>=0.5.6 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from mashumaro[msgpack]<3.15,>=3.9->dbt-adapters<2.0,>=1.1.1->dbt-fabric[PyHive]) (1.1.1)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.24.0->azure-identity>=1.14.0->dbt-fabric[PyHive]) (2.8.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from pydantic<3->dbt-core>=1.8.0->dbt-fabric[PyHive]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from pydantic<3->dbt-core>=1.8.0->dbt-fabric[PyHive]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from pydantic<3->dbt-core>=1.8.0->dbt-fabric[PyHive]) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from requests>=2.18.4->azure-core>=1.26.0->dbt-fabric[PyHive]) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from requests>=2.18.4->azure-core>=1.26.0->dbt-fabric[PyHive]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from requests>=2.18.4->azure-core>=1.26.0->dbt-fabric[PyHive]) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from requests>=2.18.4->azure-core>=1.26.0->dbt-fabric[PyHive]) (2024.7.4)
# Requirement already satisfied: pycparser in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from cffi>=1.14->cryptography>=2.5->azure-identity>=1.14.0->dbt-fabric[PyHive]) (2.22)
# Requirement already satisfied: zipp>=0.5 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from importlib-metadata<9,>=6.0->dbt-semantic-interfaces<0.10,>=0.9.0->dbt-core>=1.8.0->dbt-fabric[PyHive]) (3.23.0)
# Requirement already satisfied: text-unidecode>=1.3 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from python-slugify>=1.2.1->agate<2.0,>=1.0->dbt-adapters<2.0,>=1.1.1->dbt-fabric[PyHive]) (1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# log init
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
log_filename = f"dbt_log_{timestamp}.txt"
lakehouse_log_path = f"{lakehouse_log_dir}/{log_filename}"
log = ''
# setup local dbt folders

# vars
target_dir = f"{run_dir}/target"
log_dir = f"{run_dir}/logs"
branch_zip_path=f'{zip_src}/{git_branch}.zip'

# prep folders
print ('Preparing run-dir ',run_dir)
if os.path.exists(run_dir):
    shutil.rmtree(run_dir)
os.makedirs(run_dir, exist_ok=True)  # This will create all directories, and won't raise an error if they exist
os.makedirs(target_dir, exist_ok=True)
os.makedirs(log_dir, exist_ok=True)
notebookutils.fs.mkdirs(lakehouse_log_dir)
os.chdir(run_dir)
# Out:
# Preparing run-dir  /tmp/dbt_project

# %%
# get repo
print("unzip dbt repo", branch_zip_path, " to ", run_dir)
log+= f"unzip dbt repo {branch_zip_path} to {run_dir}\n"
with zipfile.ZipFile(branch_zip_path, "r") as zip_ref:
    zip_ref.extractall(run_dir)

# show dbt project folder and profile
log += f"\n\n📦 Listing for: {run_dir}\n"
for name in os.listdir(run_dir):
    full = os.path.join(run_dir, name)
    if os.path.isdir(full):
        log += f"📂 {name}"
    else:
        log += f"📄 {name}"

log +="\n\nProfile:"
with open("profiles.yml") as f:
    log += f.read()
# Out:
# unzip dbt repo /lakehouse/default/Files/dbt-repo-zips/main.zip  to  /tmp/dbt_project

# %%
# Pass dbt config
os.environ["DBT_TARGET_PATH"] = target_dir
os.environ["DBT_CONNECTION_STRING"] = target_connection_string
os.environ["DRIVER"] = 'ODBC Driver 18 for SQL Server'
os.environ["AUTHENTICATION"] = dbt_authentication # ActiveDirectoryAccessToken
os.environ["DATABASE"] = target_database
os.environ["ACCESS_TOKEN"] = notebookutils.credentials.getToken("https://database.windows.net/") # workspace identity access token

# %% [markdown]
# ## 4. Run dbt

# %%
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
log_filename = f"dbt_log_{timestamp}.txt"
lakehouse_log_path = f"{lakehouse_log_dir}/{log_filename}"

runner = DbtRunner(lakehouse_log_path)

cmd = f"{dbt_command} {dbt_selector} --log-format text"
runner.log(cmd)

# Header
runner.log("=" * 40)
runner.log("DBT Run Log")
runner.log(f"Run-Id: {run_id}")
runner.log(f"Timestamp: {timestamp}")
runner.log(f"Workspace: {ws_name} ({stage})")
runner.log(f"Branch: {git_branch}")
runner.log(f"Command: {dbt_command} {dbt_selector}")
runner.log("=" * 40)
runner.log("")

runner.run(cmd)
# Out:
# [2025-12-16 00:05:20] [INFO] dbt run -s fna_percelen --log-format text
# [2025-12-16 00:05:20] [INFO] ========================================
# [2025-12-16 00:05:20] [INFO] DBT Run Log
# [2025-12-16 00:05:20] [INFO] Run-Id: n/a
# [2025-12-16 00:05:20] [INFO] Timestamp: 20251216_000520
# [2025-12-16 00:05:20] [INFO] Workspace: dbt_runner1 (dev)
# [2025-12-16 00:05:20] [INFO] Branch: main
# [2025-12-16 00:05:20] [INFO] Command: dbt run -s fna_percelen
# [2025-12-16 00:05:20] [INFO] ========================================
# [2025-12-16 00:05:20] [INFO]
# [2025-12-16 00:05:20] [INFO] Starting dbt run
# [2025-12-16 00:05:22] [INFO] 00:05:22  Running with dbt=1.10.15
# [2025-12-16 00:05:23] [INFO] 00:05:23  [WARNING][DuplicateYAMLKeysDeprecation]: Deprecated functionality
# [2025-12-16 00:05:23] [INFO] Duplicate key '+schema' in "<unicode string>", line 145, column 7 in file
# [2025-12-16 00:05:23] [INFO] `/tmp/dbt_project/dbt_project.yml`
# [2025-12-16 00:05:23] [INFO] 00:05:23  Registered adapter: fabric=1.9.8
# [2025-12-16 00:05:23] [INFO] 00:05:23  Unable to do partial parsing because saved manifest not found. Starting full parse.
# [2025-12-16 00:05:26] [INFO] 00:05:26  lbt_2023: ====== lbt_diff_vs_var('lbt_target_columns') ======
# [2025-12-16 00:05:26] [INFO] 00:05:26  lbt_2023: Target columns (var): 218
# [2025-12-16 00:05:26] [INFO] 00:05:26  lbt_2023: Mapped into target   : 185
# [2025-12-16 00:05:26] [INFO] 00:05:26  lbt_2023: NULL-filled (missing): 33
# [2025-12-16 00:05:26] [INFO] 00:05:26  lbt_2023: EXTRA in model but NOT in var: <none>
# [2025-12-16 00:05:26] [INFO] 00:05:26  lbt_2023: MISSING in model (NULL-filled): lbt_status, dagleiding, gebjrleiding, gesleiding, oplbedrh, bedropv, ganstot, opbio1tot, opbio2tot, fopatot, ovpatot, pptot, pp2tot, epdtot, ovdiertot, beregenen, cbsbuit, cbsvbaki, cbsvbalb, cbsvbalvd, cbsvbaqua, cbsvbdevd, cbsvbedu, cbsvbnal, cbsvbpvbl, cbsvbstl, cbsvbtoe, cbsvbvpc, cbsvbvtc, cbsvbvwlb, cbsvbzrg, natuurbio1, natuurbio2
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2017: ====== lbt_diff_vs_var('lbt_target_columns') ======
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2017: Target columns (var): 218
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2017: Mapped into target   : 171
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2017: NULL-filled (missing): 47
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2017: EXTRA in model but NOT in var: <none>
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2017: MISSING in model (NULL-filled): xy_gr_perc, dagleiding, gebjrleiding, gesleiding, oplbedrh, bedropv, vsmtot, vsotot, lgtot, epdtot, aardappbio1, aardappbio2, cbsaardappcs, cbsaardapppt, cbsaardappzm, akkbio1, akkbio2, beregenen, cbsakk, cbsbedr3, cbsbln, cbsbostot, cbsbrlbio1, cbsbrlbio2, cbsopbio1, cbsopbio2, cbsovncg, cbssvbio1, cbssvbio2, cbsvbaki, cbsvbalb, cbsvbalvd, cbsvbaqua, cbsvbdevd, cbsvbedu, cbsvbnal, cbsvbpvbl, cbsvbstl, cbsvbtoe, cbsvbvpc, cbsvbvtc, cbsvbvwlb, cbsvbzrg, graslbio1, graslbio2, ovmelkverw, ovbeweiden
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2021: ====== lbt_diff_vs_var('lbt_target_columns') ======
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2021: Target columns (var): 218
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2021: Mapped into target   : 191
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2021: NULL-filled (missing): 27
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2021: EXTRA in model but NOT in var: <none>
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2021: MISSING in model (NULL-filled): lbt_status, dagleiding, gebjrleiding, gesleiding, oplbedrh, bedropv, ganstot, opbio1tot, opbio2tot, epdtot, ovdiertot, beregenen, cbsbuit, cbsvbaki, cbsvbalb, cbsvbalvd, cbsvbaqua, cbsvbdevd, cbsvbedu, cbsvbnal, cbsvbpvbl, cbsvbstl, cbsvbtoe, cbsvbvpc, cbsvbvtc, cbsvbvwlb, cbsvbzrg
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2018: ====== lbt_diff_vs_var('lbt_target_columns') ======
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2018: Target columns (var): 218
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2018: Mapped into target   : 192
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2018: NULL-filled (missing): 26
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2018: EXTRA in model but NOT in var: <none>
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2018: MISSING in model (NULL-filled): xy_gr_perc, dagleiding, gebjrleiding, gesleiding, oplbedrh, bedropv, ganstot, beregenen, cbsbrlbio1, cbsbrlbio2, cbsvbaki, cbsvbalb, cbsvbalvd, cbsvbaqua, cbsvbdevd, cbsvbedu, cbsvbnal, cbsvbpvbl, cbsvbstl, cbsvbtoe, cbsvbvpc, cbsvbvtc, cbsvbvwlb, cbsvbzrg, ovmelkverw, ovbeweiden
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2016: ====== lbt_diff_vs_var('lbt_target_columns') ======
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2016: Target columns (var): 218
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2016: Mapped into target   : 177
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2016: NULL-filled (missing): 41
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2016: EXTRA in model but NOT in var: <none>
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2016: MISSING in model (NULL-filled): xy_gr_perc, svc, dagleiding, gebjrleiding, gesleiding, oplbedrh, bedropv, patot, vsmtot, vsotot, lgtot, cbsaardappcs, cbsaardapppt, cbsaardappzm, akkbio1, akkbio2, beregenen, cbsakk, cbsbedr3, cbsbln, cbsbostot, cbsbrlbio1, cbsbrlbio2, cbsfrobio1, cbsfrobio2, cbsgrobio1, cbsgrobio2, cbsopbio1, cbsopbio2, cbsovncg, cbssvbio1, cbssvbio2, cbsvbalvd, cbsvbdevd, cbsvbnal, cbsvbpvbl, cbsvbvtc, graslbio1, graslbio2, ovmelkverw, ovbeweiden
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2022: ====== lbt_diff_vs_var('lbt_target_columns') ======
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2022: Target columns (var): 218
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2022: Mapped into target   : 184
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2022: NULL-filled (missing): 34
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2022: EXTRA in model but NOT in var: <none>
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2022: MISSING in model (NULL-filled): lbt_status, dagleiding, gebjrleiding, gesleiding, oplbedrh, bedropv, ganstot, opbio1tot, opbio2tot, potot, patot, fopatot, ovpatot, ezltot, pptot, pp2tot, epdtot, ovdiertot, beregenen, cbsbuit, cbsvbaki, cbsvbalb, cbsvbalvd, cbsvbaqua, cbsvbdevd, cbsvbedu, cbsvbnal, cbsvbpvbl, cbsvbstl, cbsvbtoe, cbsvbvpc, cbsvbvtc, cbsvbvwlb, cbsvbzrg
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2020: ====== lbt_diff_vs_var('lbt_target_columns') ======
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2020: Target columns (var): 218
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2020: Mapped into target   : 213
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2020: NULL-filled (missing): 5
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2020: EXTRA in model but NOT in var: <none>
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2020: MISSING in model (NULL-filled): ganstot, opbio1tot, opbio2tot, ovmelkverw, ovbeweiden
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2019: ====== lbt_diff_vs_var('lbt_target_columns') ======
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2019: Target columns (var): 218
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2019: Mapped into target   : 192
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2019: NULL-filled (missing): 26
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2019: EXTRA in model but NOT in var: <none>
# [2025-12-16 00:05:27] [INFO] 00:05:27  lbt_2019: MISSING in model (NULL-filled): xy_gr_perc, dagleiding, gebjrleiding, gesleiding, oplbedrh, bedropv, ganstot, beregenen, cbsbrlbio1, cbsbrlbio2, cbsvbaki, cbsvbalb, cbsvbalvd, cbsvbaqua, cbsvbdevd, cbsvbedu, cbsvbnal, cbsvbpvbl, cbsvbstl, cbsvbtoe, cbsvbvpc, cbsvbvtc, cbsvbvwlb, cbsvbzrg, ovmelkverw, ovbeweiden
# [2025-12-16 00:05:30] [INFO] 00:05:30  [WARNING][MissingArgumentsPropertyInGenericTestDeprecation]: Deprecated
# [2025-12-16 00:05:30] [INFO] functionality
# [2025-12-16 00:05:30] [INFO] Found top-level arguments to test `relationships`. Arguments to generic tests
# [2025-12-16 00:05:30] [INFO] should be nested under the `arguments` property.`
# [2025-12-16 00:05:32] [INFO] 00:05:32  [WARNING]: Did not find matching node for patch with name 'Dim_Behandelaar' in the 'models' section of file 'models/loket/_schema.yml'
# [2025-12-16 00:05:32] [INFO] 00:05:32  [WARNING]: Did not find matching node for patch with name 'Dim_Klant' in the 'models' section of file 'models/loket/_schema.yml'
# [2025-12-16 00:05:32] [INFO] 00:05:32  [WARNING]: Did not find matching node for patch with name 'Dim_Ticket' in the 'models' section of file 'models/loket/_schema.yml'
# [2025-12-16 00:05:32] [INFO] 00:05:32  [WARNING]: Did not find matching node for patch with name 'Fact_Ticket' in the 'models' section of file 'models/loket/_schema.yml'
# [2025-12-16 00:05:32] [INFO] 00:05:32  [WARNING]: Did not find matching node for patch with name 'im_sub_dim_zaak_status_wijziging' in the 'models' section of file 'models/im_sub/_schema.yml'
# [2025-12-16 00:05:32] [INFO] 00:05:32  [WARNING]: Did not find matching node for patch with name 'fact_realisatiejournaal' in the 'models' section of file 'models/fin/_schema.yml'
# [2025-12-16 00:05:33] [INFO] 00:05:32  [WARNING]: Did not find matching node for patch with name 'fact_budgethouderpersegment' in the 'models' section of file 'models/fin/_schema.yml'
# [2025-12-16 00:05:33] [INFO] 00:05:32  [WARNING]: Did not find matching node for patch with name 'fact_budgetjournaal' in the 'models' section of file 'models/fin/_schema.yml'
# [2025-12-16 00:05:33] [INFO] 00:05:32  [WARNING]: Did not find matching node for patch with name 'fact_budgetmutaties' in the 'models' section of file 'models/fin/_schema.yml'
# [2025-12-16 00:05:33] [INFO] 00:05:32  [WARNING]: Did not find matching node for patch with name 'fact_budgetsaldi' in the 'models' section of file 'models/fin/_schema.yml'
# [2025-12-16 00:05:33] [INFO] 00:05:32  [WARNING]: Did not find matching node for patch with name 'fact_factureninomloop' in the 'models' section of file 'models/fin/_schema.yml'
# [2025-12-16 00:05:33] [INFO] 00:05:32  [WARNING]: Did not find matching node for patch with name 'fact_grootboeksaldi' in the 'models' section of file 'models/fin/_schema.yml'
# [2025-12-16 00:05:33] [INFO] 00:05:32  [WARNING]: Did not find matching node for patch with name 'fact_journaalsaldi' in the 'models' section of file 'models/fin/_schema.yml'
# [2025-12-16 00:05:33] [INFO] 00:05:32  [WARNING]: Did not find matching node for patch with name 'fact_reserveringjournaal' in the 'models' section of file 'models/fin/_schema.yml'
# [2025-12-16 00:05:33] [INFO] 00:05:32  [WARNING]: Did not find matching node for patch with name 'fact_schatkistdeposito' in the 'models' section of file 'models/fin/_schema.yml'
# [2025-12-16 00:05:33] [INFO] 00:05:32  [WARNING]: Did not find matching node for patch with name 'fact_verplichtingjournaal' in the 'models' section of file 'models/fin/_schema.yml'
# [2025-12-16 00:05:33] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_sub_dim_aanvraagtitel_dim_medewerker_verrichter_sqn__dim_medewerker_sqn___ref_sub_conformed_dim_medewerker_.c5faade82d' (models/sub/_schema.yml) depends on a node named 'sub_conformed_dim_medewerker' in package '' which was not found
# [2025-12-16 00:05:33] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_dm_telling_Telvak__Telvak___ref_Telvak_.2fc4e96f4e' (models/bow_vis/_schema.yml) depends on a node named 'Telvak' in package '' which was not found
# [2025-12-16 00:05:33] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.unique_Dim_Behandelaar_Dim_Behandelaar_SQN.9e287ba2fa' (models/loket/_schema.yml) depends on a node named 'Dim_Behandelaar' in package '' which was not found
# [2025-12-16 00:05:33] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.not_null_Dim_Behandelaar_Dim_Behandelaar_SQN.2568f0e17d' (models/loket/_schema.yml) depends on a node named 'Dim_Behandelaar' in package '' which was not found
# [2025-12-16 00:05:33] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.unique_Dim_Klant_Dim_Klant_SQN.f962fff95d' (models/loket/_schema.yml) depends on a node named 'Dim_Klant' in package '' which was not found
# [2025-12-16 00:05:33] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.not_null_Dim_Klant_Dim_Klant_SQN.3c778b85d3' (models/loket/_schema.yml) depends on a node named 'Dim_Klant' in package '' which was not found
# [2025-12-16 00:05:33] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.unique_Dim_Ticket_Dim_Ticket_SQN.7ce4b35721' (models/loket/_schema.yml) depends on a node named 'Dim_Ticket' in package '' which was not found
# [2025-12-16 00:05:33] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.not_null_Dim_Ticket_Dim_Ticket_SQN.627d2f1ad2' (models/loket/_schema.yml) depends on a node named 'Dim_Ticket' in package '' which was not found
# [2025-12-16 00:05:33] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.unique_Fact_Ticket_Fact_Ticket_SQN.207f4caae9' (models/loket/_schema.yml) depends on a node named 'Fact_Ticket' in package '' which was not found
# [2025-12-16 00:05:33] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.not_null_Fact_Ticket_Fact_Ticket_SQN.92cc844aa0' (models/loket/_schema.yml) depends on a node named 'Fact_Ticket' in package '' which was not found
# [2025-12-16 00:05:33] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_Fact_Ticket_Dim_Behandelaar_SQN__Dim_Behandelaar_SQN___ref_dim_behandelaar_.8e8f14f339' (models/loket/_schema.yml) depends on a node named 'Fact_Ticket' in package '' which was not found
# [2025-12-16 00:05:33] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_Fact_Ticket_Dim_Klant_SQN__Dim_Klant_SQN___ref_dim_klant_.d7db5ccaab' (models/loket/_schema.yml) depends on a node named 'Fact_Ticket' in package '' which was not found
# [2025-12-16 00:05:33] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_Fact_Ticket_Dim_Ticket_SQN__Dim_Ticket_SQN___ref_dim_ticket_.0f1f1673e1' (models/loket/_schema.yml) depends on a node named 'Fact_Ticket' in package '' which was not found
# [2025-12-16 00:05:33] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.unique_im_sub_dim_zaak_status_wijziging_dim_zaak_status_wijziging_sqn.f81fd931f7' (models/im_sub/_schema.yml) depends on a node named 'im_sub_dim_zaak_status_wijziging' in package '' which was not found
# [2025-12-16 00:05:33] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.not_null_im_sub_dim_zaak_status_wijziging_dim_zaak_status_wijziging_sqn.931b136506' (models/im_sub/_schema.yml) depends on a node named 'im_sub_dim_zaak_status_wijziging' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.unique_fact_realisatiejournaal_fact_realisatiejournaal_sqn.cc9af9c987' (models/fin/_schema.yml) depends on a node named 'fact_realisatiejournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.not_null_fact_realisatiejournaal_fact_realisatiejournaal_sqn.e4dde98122' (models/fin/_schema.yml) depends on a node named 'fact_realisatiejournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_realisatiejournaal_dim_boekingscombinatie_sqn__dim_boekingscombinatie_sqn___ref_dim_boekingscombinatie_.b2e4d853a6' (models/fin/_schema.yml) depends on a node named 'dim_boekingscombinatie' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_realisatiejournaal_dim_boekingscombinatie_sqn__dim_boekingscombinatie_sqn___ref_dim_boekingscombinatie_.b2e4d853a6' (models/fin/_schema.yml) depends on a node named 'fact_realisatiejournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_realisatiejournaal_dim_taakveld_sqn__dim_taakveld_sqn___ref_dim_taakveld_.e05e6363eb' (models/fin/_schema.yml) depends on a node named 'dim_taakveld' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_realisatiejournaal_dim_taakveld_sqn__dim_taakveld_sqn___ref_dim_taakveld_.e05e6363eb' (models/fin/_schema.yml) depends on a node named 'fact_realisatiejournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_realisatiejournaal_dim_thema_sqn__dim_thema_sqn___ref_fin_conformed_dim_thema_.4ebd6048b8' (models/fin/_schema.yml) depends on a node named 'fact_realisatiejournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_realisatiejournaal_dim_tactischdoel_sqn__dim_tactischdoel_sqn___ref_fin_conformed_dim_tactischdoel_.0386284e59' (models/fin/_schema.yml) depends on a node named 'fact_realisatiejournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_realisatiejournaal_dim_ambitie_sqn__dim_ambitie_sqn___ref_dim_ambitie_.1d790e1b76' (models/fin/_schema.yml) depends on a node named 'dim_ambitie' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_realisatiejournaal_dim_ambitie_sqn__dim_ambitie_sqn___ref_dim_ambitie_.1d790e1b76' (models/fin/_schema.yml) depends on a node named 'fact_realisatiejournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_realisatiejournaal_dim_rvt_3pos_sqn__dim_rvt_3pos_sqn___ref_fin_conformed_dim_rvt_3pos_.8d44d7d9a5' (models/fin/_schema.yml) depends on a node named 'fact_realisatiejournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_realisatiejournaal_dim_rvt_sqn__dim_rvt_sqn___ref_dim_rvt_.24f5cb3449' (models/fin/_schema.yml) depends on a node named 'dim_rvt' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_realisatiejournaal_dim_rvt_sqn__dim_rvt_sqn___ref_dim_rvt_.24f5cb3449' (models/fin/_schema.yml) depends on a node named 'fact_realisatiejournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_realisatiejournaal_dim_productjaar_sqn__dim_productjaar_sqn___ref_dim_productjaar_.9e1a74de4c' (models/fin/_schema.yml) depends on a node named 'dim_productjaar' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_realisatiejournaal_dim_productjaar_sqn__dim_productjaar_sqn___ref_dim_productjaar_.9e1a74de4c' (models/fin/_schema.yml) depends on a node named 'fact_realisatiejournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_realisatiejournaal_dim_boekingsperiode_sqn__dim_boekingsperiode_sqn___ref_fin_conformed_dim_boekingsperiode_.46be75f724' (models/fin/_schema.yml) depends on a node named 'fact_realisatiejournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_realisatiejournaal_dim_fonds_sqn__dim_fonds_sqn___ref_fin_conformed_dim_fonds_.ff1b014230' (models/fin/_schema.yml) depends on a node named 'fact_realisatiejournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_realisatiejournaal_dim_kalender_sqn__dim_kalender_sqn___ref_dim_kalender_.de6f510a9a' (models/fin/_schema.yml) depends on a node named 'fact_realisatiejournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_realisatiejournaal_dim_realisatiejournaal_sqn__dim_realisatiejournaal_sqn___ref_fin_conformed_dim_realisatiejournaal_.cd9edef8c6' (models/fin/_schema.yml) depends on a node named 'fin_conformed_dim_realisatiejournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_realisatiejournaal_dim_realisatiejournaal_sqn__dim_realisatiejournaal_sqn___ref_fin_conformed_dim_realisatiejournaal_.cd9edef8c6' (models/fin/_schema.yml) depends on a node named 'fact_realisatiejournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_realisatiejournaal_dim_klant_sqn__dim_klant_sqn___ref_fin_conformed_dim_klant_.9912605e98' (models/fin/_schema.yml) depends on a node named 'fact_realisatiejournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_realisatiejournaal_dim_leverancier_sqn__dim_leverancier_sqn___ref_fin_conformed_dim_leverancier_.5d7c7e6d89' (models/fin/_schema.yml) depends on a node named 'fact_realisatiejournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_realisatiejournaal_dim_rvt_balans_sqn__dim_rvt_balans_sqn___ref_dim_rvt_balans_.ed54affcbb' (models/fin/_schema.yml) depends on a node named 'dim_rvt_balans' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_realisatiejournaal_dim_rvt_balans_sqn__dim_rvt_balans_sqn___ref_dim_rvt_balans_.ed54affcbb' (models/fin/_schema.yml) depends on a node named 'fact_realisatiejournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_realisatiejournaal_dim_rapportage_filters_2_sqn__dim_rapportage_filters_2_sqn___ref_fin_conformed_dim_rapportage_filters_2_.08673476e5' (models/fin/_schema.yml) depends on a node named 'fact_realisatiejournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_realisatiejournaal_dim_rapportage_filters_1_sqn__dim_rapportage_filters_1_sqn___ref_fin_conformed_dim_rapportage_filters_1_.31a1dc1276' (models/fin/_schema.yml) depends on a node named 'fact_realisatiejournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_realisatiejournaal_dim_lb_categorie_sqn__dim_lb_categorie_sqn___ref_dim_lb_categorie_.d86e419cc7' (models/fin/_schema.yml) depends on a node named 'dim_lb_categorie' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_realisatiejournaal_dim_lb_categorie_sqn__dim_lb_categorie_sqn___ref_dim_lb_categorie_.d86e419cc7' (models/fin/_schema.yml) depends on a node named 'fact_realisatiejournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.unique_fact_budgethouderpersegment_fact_budgethouderpersegment_sqn.dd6e5d2d7f' (models/fin/_schema.yml) depends on a node named 'fact_budgethouderpersegment' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.not_null_fact_budgethouderpersegment_fact_budgethouderpersegment_sqn.b283270565' (models/fin/_schema.yml) depends on a node named 'fact_budgethouderpersegment' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_budgethouderpersegment_dim_budgethouder_sqn__dim_budgethouder_sqn___ref_fin_conformed_dim_budgethouder_.b14a9fa56f' (models/fin/_schema.yml) depends on a node named 'fact_budgethouderpersegment' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_budgethouderpersegment_dim_budgethouderpersegment_sqn__dim_budgethouderpersegment_sqn___ref_dim_budgethouderpersegment_.7712c61d6c' (models/fin/_schema.yml) depends on a node named 'dim_budgethouderpersegment' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_budgethouderpersegment_dim_budgethouderpersegment_sqn__dim_budgethouderpersegment_sqn___ref_dim_budgethouderpersegment_.7712c61d6c' (models/fin/_schema.yml) depends on a node named 'fact_budgethouderpersegment' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_budgethouderpersegment_dim_product_sqn__dim_product_sqn___ref_dim_product_.47c487d3fe' (models/fin/_schema.yml) depends on a node named 'dim_product' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_budgethouderpersegment_dim_product_sqn__dim_product_sqn___ref_dim_product_.47c487d3fe' (models/fin/_schema.yml) depends on a node named 'fact_budgethouderpersegment' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_budgethouderpersegment_dim_project_sqn__dim_project_sqn___ref_fin_conformed_dim_project_.91017efbf9' (models/fin/_schema.yml) depends on a node named 'fact_budgethouderpersegment' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_budgethouderpersegment_dim_specificatie_sqn__dim_specificatie_sqn___ref_fin_conformed_dim_specificatie_.aa358bf323' (models/fin/_schema.yml) depends on a node named 'fin_conformed_dim_specificatie' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_budgethouderpersegment_dim_specificatie_sqn__dim_specificatie_sqn___ref_fin_conformed_dim_specificatie_.aa358bf323' (models/fin/_schema.yml) depends on a node named 'fact_budgethouderpersegment' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_budgethouderpersegment_dim_team_financieel_sqn__dim_team_financieel_sqn___ref_fin_conformed_dim_team_financieel_.936c4e8505' (models/fin/_schema.yml) depends on a node named 'fact_budgethouderpersegment' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.unique_fact_budgetjournaal_fact_budgetjournaal_sqn.f2f60caf79' (models/fin/_schema.yml) depends on a node named 'fact_budgetjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.not_null_fact_budgetjournaal_fact_budgetjournaal_sqn.8c5659d924' (models/fin/_schema.yml) depends on a node named 'fact_budgetjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_budgetjournaal_dim_boekingscombinatie_sqn__dim_boekingscombinatie_sqn___ref_dim_boekingscombinatie_.cbf5fc2841' (models/fin/_schema.yml) depends on a node named 'dim_boekingscombinatie' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_budgetjournaal_dim_boekingscombinatie_sqn__dim_boekingscombinatie_sqn___ref_dim_boekingscombinatie_.cbf5fc2841' (models/fin/_schema.yml) depends on a node named 'fact_budgetjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_budgetjournaal_dim_taakveld_sqn__dim_taakveld_sqn___ref_dim_taakveld_.f96034539a' (models/fin/_schema.yml) depends on a node named 'dim_taakveld' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_budgetjournaal_dim_taakveld_sqn__dim_taakveld_sqn___ref_dim_taakveld_.f96034539a' (models/fin/_schema.yml) depends on a node named 'fact_budgetjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_budgetjournaal_dim_thema_sqn__dim_thema_sqn___ref_fin_conformed_dim_thema_.b03cb244a2' (models/fin/_schema.yml) depends on a node named 'fact_budgetjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_budgetjournaal_dim_tactischdoel_sqn__dim_tactischdoel_sqn___ref_fin_conformed_dim_tactischdoel_.3ceb27748f' (models/fin/_schema.yml) depends on a node named 'fact_budgetjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_budgetjournaal_dim_ambitie_sqn__dim_ambitie_sqn___ref_dim_ambitie_.33e8f71eb9' (models/fin/_schema.yml) depends on a node named 'dim_ambitie' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_budgetjournaal_dim_ambitie_sqn__dim_ambitie_sqn___ref_dim_ambitie_.33e8f71eb9' (models/fin/_schema.yml) depends on a node named 'fact_budgetjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_budgetjournaal_dim_rvt_3pos_sqn__dim_rvt_3pos_sqn___ref_fin_conformed_dim_rvt_3pos_.af73da1ad1' (models/fin/_schema.yml) depends on a node named 'fact_budgetjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_budgetjournaal_dim_rvt_sqn__dim_rvt_sqn___ref_dim_rvt_.cb850852d5' (models/fin/_schema.yml) depends on a node named 'dim_rvt' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:33  [WARNING]: Test 'test.dwh.relationships_fact_budgetjournaal_dim_rvt_sqn__dim_rvt_sqn___ref_dim_rvt_.cb850852d5' (models/fin/_schema.yml) depends on a node named 'fact_budgetjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetjournaal_dim_productjaar_sqn__dim_productjaar_sqn___ref_dim_productjaar_.420b2c98e9' (models/fin/_schema.yml) depends on a node named 'dim_productjaar' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetjournaal_dim_productjaar_sqn__dim_productjaar_sqn___ref_dim_productjaar_.420b2c98e9' (models/fin/_schema.yml) depends on a node named 'fact_budgetjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetjournaal_dim_begrotingswijziging_sqn__dim_begrotingswijziging_sqn___ref_dim_begrotingswijziging_.d8da215c9a' (models/fin/_schema.yml) depends on a node named 'dim_begrotingswijziging' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetjournaal_dim_begrotingswijziging_sqn__dim_begrotingswijziging_sqn___ref_dim_begrotingswijziging_.d8da215c9a' (models/fin/_schema.yml) depends on a node named 'fact_budgetjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetjournaal_dim_eenmalig_structureel_sqn__dim_eenmalig_structureel_sqn___ref_fin_conformed_dim_eenmalig_structureel_.9275659b03' (models/fin/_schema.yml) depends on a node named 'fin_conformed_dim_eenmalig_structureel' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetjournaal_dim_eenmalig_structureel_sqn__dim_eenmalig_structureel_sqn___ref_fin_conformed_dim_eenmalig_structureel_.9275659b03' (models/fin/_schema.yml) depends on a node named 'fact_budgetjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetjournaal_dim_budgetjournaal_sqn__dim_budgetjournaal_sqn___ref_fin_conformed_dim_budgetjournaal_.8125b92fa2' (models/fin/_schema.yml) depends on a node named 'fin_conformed_dim_budgetjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetjournaal_dim_budgetjournaal_sqn__dim_budgetjournaal_sqn___ref_fin_conformed_dim_budgetjournaal_.8125b92fa2' (models/fin/_schema.yml) depends on a node named 'fact_budgetjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetjournaal_dim_budget_batch_sqn__dim_budget_batch_sqn___ref_dim_budget_batch_.7173c75050' (models/fin/_schema.yml) depends on a node named 'dim_budget_batch' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetjournaal_dim_budget_batch_sqn__dim_budget_batch_sqn___ref_dim_budget_batch_.7173c75050' (models/fin/_schema.yml) depends on a node named 'fact_budgetjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetjournaal_dim_boekingsperiode_sqn__dim_boekingsperiode_sqn___ref_fin_conformed_dim_boekingsperiode_.53c4f17cb1' (models/fin/_schema.yml) depends on a node named 'fact_budgetjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetjournaal_dim_fonds_sqn__dim_fonds_sqn___ref_fin_conformed_dim_fonds_.c5838bd6ce' (models/fin/_schema.yml) depends on a node named 'fact_budgetjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetjournaal_dim_kalender_sqn__dim_kalender_sqn___ref_dim_kalender_.3e4aa3b301' (models/fin/_schema.yml) depends on a node named 'fact_budgetjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetjournaal_dim_rapportage_filters_2_sqn__dim_rapportage_filters_2_sqn___ref_fin_conformed_dim_rapportage_filters_2_.8c2b8a7db1' (models/fin/_schema.yml) depends on a node named 'fact_budgetjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetjournaal_dim_rapportage_filters_1_sqn__dim_rapportage_filters_1_sqn___ref_fin_conformed_dim_rapportage_filters_1_.b8b77af436' (models/fin/_schema.yml) depends on a node named 'fact_budgetjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetjournaal_dim_lb_categorie_sqn__dim_lb_categorie_sqn___ref_dim_lb_categorie_.3f2e193e2a' (models/fin/_schema.yml) depends on a node named 'dim_lb_categorie' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetjournaal_dim_lb_categorie_sqn__dim_lb_categorie_sqn___ref_dim_lb_categorie_.3f2e193e2a' (models/fin/_schema.yml) depends on a node named 'fact_budgetjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.unique_fact_budgetmutaties_fact_budgetmutaties_sqn.ba53dcf27d' (models/fin/_schema.yml) depends on a node named 'fact_budgetmutaties' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.not_null_fact_budgetmutaties_fact_budgetmutaties_sqn.4b7f04f511' (models/fin/_schema.yml) depends on a node named 'fact_budgetmutaties' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetmutaties_dim_boekingscombinatie_sqn__dim_boekingscombinatie_sqn___ref_dim_boekingscombinatie_.ad158b0ff6' (models/fin/_schema.yml) depends on a node named 'dim_boekingscombinatie' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetmutaties_dim_boekingscombinatie_sqn__dim_boekingscombinatie_sqn___ref_dim_boekingscombinatie_.ad158b0ff6' (models/fin/_schema.yml) depends on a node named 'fact_budgetmutaties' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetmutaties_dim_taakveld_sqn__dim_taakveld_sqn___ref_dim_taakveld_.26c1308298' (models/fin/_schema.yml) depends on a node named 'dim_taakveld' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetmutaties_dim_taakveld_sqn__dim_taakveld_sqn___ref_dim_taakveld_.26c1308298' (models/fin/_schema.yml) depends on a node named 'fact_budgetmutaties' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetmutaties_dim_thema_sqn__dim_thema_sqn___ref_fin_conformed_dim_thema_.855dcf9175' (models/fin/_schema.yml) depends on a node named 'fact_budgetmutaties' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetmutaties_dim_tactischdoel_sqn__dim_tactischdoel_sqn___ref_fin_conformed_dim_tactischdoel_.146fb061ba' (models/fin/_schema.yml) depends on a node named 'fact_budgetmutaties' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetmutaties_dim_ambitie_sqn__dim_ambitie_sqn___ref_dim_ambitie_.ead6e5f137' (models/fin/_schema.yml) depends on a node named 'dim_ambitie' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetmutaties_dim_ambitie_sqn__dim_ambitie_sqn___ref_dim_ambitie_.ead6e5f137' (models/fin/_schema.yml) depends on a node named 'fact_budgetmutaties' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetmutaties_dim_rvt_3pos_sqn__dim_rvt_3pos_sqn___ref_fin_conformed_dim_rvt_3pos_.e446653b9f' (models/fin/_schema.yml) depends on a node named 'fact_budgetmutaties' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetmutaties_dim_rvt_sqn__dim_rvt_sqn___ref_dim_rvt_.9834efe64e' (models/fin/_schema.yml) depends on a node named 'dim_rvt' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetmutaties_dim_rvt_sqn__dim_rvt_sqn___ref_dim_rvt_.9834efe64e' (models/fin/_schema.yml) depends on a node named 'fact_budgetmutaties' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetmutaties_dim_productjaar_sqn__dim_productjaar_sqn___ref_dim_productjaar_.9b8d532108' (models/fin/_schema.yml) depends on a node named 'dim_productjaar' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetmutaties_dim_productjaar_sqn__dim_productjaar_sqn___ref_dim_productjaar_.9b8d532108' (models/fin/_schema.yml) depends on a node named 'fact_budgetmutaties' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetmutaties_dim_budgetjournaal_sqn__dim_budgetjournaal_sqn___ref_fin_conformed_dim_budgetjournaal_.2c69272f99' (models/fin/_schema.yml) depends on a node named 'fin_conformed_dim_budgetjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetmutaties_dim_budgetjournaal_sqn__dim_budgetjournaal_sqn___ref_fin_conformed_dim_budgetjournaal_.2c69272f99' (models/fin/_schema.yml) depends on a node named 'fact_budgetmutaties' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetmutaties_dim_boekingsperiode_sqn__dim_boekingsperiode_sqn___ref_fin_conformed_dim_boekingsperiode_.94506d3fd8' (models/fin/_schema.yml) depends on a node named 'fact_budgetmutaties' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetmutaties_dim_boekjaar_sqn__dim_boekjaar_sqn___ref_fin_conformed_dim_boekjaar_.d3dd745b71' (models/fin/_schema.yml) depends on a node named 'fact_budgetmutaties' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetmutaties_dim_begrotingswijziging_sqn__dim_begrotingswijziging_sqn___ref_dim_begrotingswijziging_.0ebe059ba8' (models/fin/_schema.yml) depends on a node named 'dim_begrotingswijziging' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetmutaties_dim_begrotingswijziging_sqn__dim_begrotingswijziging_sqn___ref_dim_begrotingswijziging_.0ebe059ba8' (models/fin/_schema.yml) depends on a node named 'fact_budgetmutaties' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetmutaties_dim_eenmalig_structureel_sqn__dim_eenmalig_structureel_sqn___ref_fin_conformed_dim_eenmalig_structureel_.c234f6173d' (models/fin/_schema.yml) depends on a node named 'fin_conformed_dim_eenmalig_structureel' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetmutaties_dim_eenmalig_structureel_sqn__dim_eenmalig_structureel_sqn___ref_fin_conformed_dim_eenmalig_structureel_.c234f6173d' (models/fin/_schema.yml) depends on a node named 'fact_budgetmutaties' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetmutaties_dim_fonds_sqn__dim_fonds_sqn___ref_fin_conformed_dim_fonds_.64a08ec5dc' (models/fin/_schema.yml) depends on a node named 'fact_budgetmutaties' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetmutaties_dim_rapportage_filters_2_sqn__dim_rapportage_filters_2_sqn___ref_fin_conformed_dim_rapportage_filters_2_.9cfe90b233' (models/fin/_schema.yml) depends on a node named 'fact_budgetmutaties' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetmutaties_dim_rapportage_filters_1_sqn__dim_rapportage_filters_1_sqn___ref_fin_conformed_dim_rapportage_filters_1_.fa2c907249' (models/fin/_schema.yml) depends on a node named 'fact_budgetmutaties' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetmutaties_dim_lb_categorie_sqn__dim_lb_categorie_sqn___ref_dim_lb_categorie_.182c23afb7' (models/fin/_schema.yml) depends on a node named 'dim_lb_categorie' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetmutaties_dim_lb_categorie_sqn__dim_lb_categorie_sqn___ref_dim_lb_categorie_.182c23afb7' (models/fin/_schema.yml) depends on a node named 'fact_budgetmutaties' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.unique_fact_budgetsaldi_fact_budgetsaldi_sqn.eea3ff9afc' (models/fin/_schema.yml) depends on a node named 'fact_budgetsaldi' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.not_null_fact_budgetsaldi_fact_budgetsaldi_sqn.1acbe3bb05' (models/fin/_schema.yml) depends on a node named 'fact_budgetsaldi' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetsaldi_dim_boekingscombinatie_sqn__dim_boekingscombinatie_sqn___ref_dim_boekingscombinatie_.bf2b5f8a8b' (models/fin/_schema.yml) depends on a node named 'dim_boekingscombinatie' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetsaldi_dim_boekingscombinatie_sqn__dim_boekingscombinatie_sqn___ref_dim_boekingscombinatie_.bf2b5f8a8b' (models/fin/_schema.yml) depends on a node named 'fact_budgetsaldi' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetsaldi_dim_taakveld_sqn__dim_taakveld_sqn___ref_dim_taakveld_.26e4ee3307' (models/fin/_schema.yml) depends on a node named 'dim_taakveld' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetsaldi_dim_taakveld_sqn__dim_taakveld_sqn___ref_dim_taakveld_.26e4ee3307' (models/fin/_schema.yml) depends on a node named 'fact_budgetsaldi' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetsaldi_dim_thema_sqn__dim_thema_sqn___ref_fin_conformed_dim_thema_.4ec08595d5' (models/fin/_schema.yml) depends on a node named 'fact_budgetsaldi' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetsaldi_dim_tactischdoel_sqn__dim_tactischdoel_sqn___ref_fin_conformed_dim_tactischdoel_.f955321ce5' (models/fin/_schema.yml) depends on a node named 'fact_budgetsaldi' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetsaldi_dim_ambitie_sqn__dim_ambitie_sqn___ref_dim_ambitie_.7cddcf5e2f' (models/fin/_schema.yml) depends on a node named 'dim_ambitie' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetsaldi_dim_ambitie_sqn__dim_ambitie_sqn___ref_dim_ambitie_.7cddcf5e2f' (models/fin/_schema.yml) depends on a node named 'fact_budgetsaldi' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetsaldi_dim_rvt_3pos_sqn__dim_rvt_3pos_sqn___ref_fin_conformed_dim_rvt_3pos_.39ad9914c7' (models/fin/_schema.yml) depends on a node named 'fact_budgetsaldi' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetsaldi_dim_rvt_sqn__dim_rvt_sqn___ref_dim_rvt_.f1d82c057c' (models/fin/_schema.yml) depends on a node named 'dim_rvt' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetsaldi_dim_rvt_sqn__dim_rvt_sqn___ref_dim_rvt_.f1d82c057c' (models/fin/_schema.yml) depends on a node named 'fact_budgetsaldi' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetsaldi_dim_productjaar_sqn__dim_productjaar_sqn___ref_dim_productjaar_.f621824950' (models/fin/_schema.yml) depends on a node named 'dim_productjaar' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetsaldi_dim_productjaar_sqn__dim_productjaar_sqn___ref_dim_productjaar_.f621824950' (models/fin/_schema.yml) depends on a node named 'fact_budgetsaldi' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetsaldi_dim_boekjaar_sqn__dim_boekjaar_sqn___ref_fin_conformed_dim_boekjaar_.11310af929' (models/fin/_schema.yml) depends on a node named 'fact_budgetsaldi' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetsaldi_dim_begrotingswijziging_sqn__dim_begrotingswijziging_sqn___ref_dim_begrotingswijziging_.a70af8be7f' (models/fin/_schema.yml) depends on a node named 'dim_begrotingswijziging' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetsaldi_dim_begrotingswijziging_sqn__dim_begrotingswijziging_sqn___ref_dim_begrotingswijziging_.a70af8be7f' (models/fin/_schema.yml) depends on a node named 'fact_budgetsaldi' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetsaldi_dim_eenmalig_structureel_sqn__dim_eenmalig_structureel_sqn___ref_fin_conformed_dim_eenmalig_structureel_.f11666ee28' (models/fin/_schema.yml) depends on a node named 'fin_conformed_dim_eenmalig_structureel' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_budgetsaldi_dim_eenmalig_structureel_sqn__dim_eenmalig_structureel_sqn___ref_fin_conformed_dim_eenmalig_structureel_.f11666ee28' (models/fin/_schema.yml) depends on a node named 'fact_budgetsaldi' in package '' which was not found
# ...
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_reserveringjournaal_dim_taakveld_sqn__dim_taakveld_sqn___ref_dim_taakveld_.dbd80ca569' (models/fin/_schema.yml) depends on a node named 'fact_reserveringjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_reserveringjournaal_dim_thema_sqn__dim_thema_sqn___ref_fin_conformed_dim_thema_.682f6da754' (models/fin/_schema.yml) depends on a node named 'fact_reserveringjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_reserveringjournaal_dim_tactischdoel_sqn__dim_tactischdoel_sqn___ref_fin_conformed_dim_tactischdoel_.d6e183e98d' (models/fin/_schema.yml) depends on a node named 'fact_reserveringjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_reserveringjournaal_dim_ambitie_sqn__dim_ambitie_sqn___ref_dim_ambitie_.fbd00e371a' (models/fin/_schema.yml) depends on a node named 'dim_ambitie' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_reserveringjournaal_dim_ambitie_sqn__dim_ambitie_sqn___ref_dim_ambitie_.fbd00e371a' (models/fin/_schema.yml) depends on a node named 'fact_reserveringjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_reserveringjournaal_dim_rvt_3pos_sqn__dim_rvt_3pos_sqn___ref_fin_conformed_dim_rvt_3pos_.0dc1b64c84' (models/fin/_schema.yml) depends on a node named 'fact_reserveringjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_reserveringjournaal_dim_rvt_sqn__dim_rvt_sqn___ref_dim_rvt_.c24279f7fb' (models/fin/_schema.yml) depends on a node named 'dim_rvt' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_reserveringjournaal_dim_rvt_sqn__dim_rvt_sqn___ref_dim_rvt_.c24279f7fb' (models/fin/_schema.yml) depends on a node named 'fact_reserveringjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_reserveringjournaal_dim_productjaar_sqn__dim_productjaar_sqn___ref_dim_productjaar_.14a5090274' (models/fin/_schema.yml) depends on a node named 'dim_productjaar' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_reserveringjournaal_dim_productjaar_sqn__dim_productjaar_sqn___ref_dim_productjaar_.14a5090274' (models/fin/_schema.yml) depends on a node named 'fact_reserveringjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_reserveringjournaal_dim_boekingsperiode_sqn__dim_boekingsperiode_sqn___ref_fin_conformed_dim_boekingsperiode_.dfc32f2fe8' (models/fin/_schema.yml) depends on a node named 'fact_reserveringjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_reserveringjournaal_dim_kalender_sqn__dim_kalender_sqn___ref_dim_kalender_.288223bf40' (models/fin/_schema.yml) depends on a node named 'fact_reserveringjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_reserveringjournaal_dim_leverancier_sqn__dim_leverancier_sqn___ref_fin_conformed_dim_leverancier_.e044e9fefe' (models/fin/_schema.yml) depends on a node named 'fact_reserveringjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_reserveringjournaal_dim_rapportage_filters_2_sqn__dim_rapportage_filters_2_sqn___ref_fin_conformed_dim_rapportage_filters_2_.8ed2f0c68d' (models/fin/_schema.yml) depends on a node named 'fact_reserveringjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_reserveringjournaal_dim_rapportage_filters_1_sqn__dim_rapportage_filters_1_sqn___ref_fin_conformed_dim_rapportage_filters_1_.7ba6119c60' (models/fin/_schema.yml) depends on a node named 'fact_reserveringjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_reserveringjournaal_dim_lb_categorie_sqn__dim_lb_categorie_sqn___ref_dim_lb_categorie_.00f0197cf1' (models/fin/_schema.yml) depends on a node named 'dim_lb_categorie' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_reserveringjournaal_dim_lb_categorie_sqn__dim_lb_categorie_sqn___ref_dim_lb_categorie_.00f0197cf1' (models/fin/_schema.yml) depends on a node named 'fact_reserveringjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.unique_fact_schatkistdeposito_fact_schatkistdeposito_sqn.3cb3157625' (models/fin/_schema.yml) depends on a node named 'fact_schatkistdeposito' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.not_null_fact_schatkistdeposito_fact_schatkistdeposito_sqn.ce2fd0b895' (models/fin/_schema.yml) depends on a node named 'fact_schatkistdeposito' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_schatkistdeposito_dim_boekingscombinatie_sqn__dim_boekingscombinatie_sqn___ref_dim_boekingscombinatie_.09283b2985' (models/fin/_schema.yml) depends on a node named 'dim_boekingscombinatie' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_schatkistdeposito_dim_boekingscombinatie_sqn__dim_boekingscombinatie_sqn___ref_dim_boekingscombinatie_.09283b2985' (models/fin/_schema.yml) depends on a node named 'fact_schatkistdeposito' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_schatkistdeposito_dim_schatkistdeposito_sqn__dim_schatkistdeposito_sqn___ref_dim_schatkistdeposito_.712d996413' (models/fin/_schema.yml) depends on a node named 'dim_schatkistdeposito' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_schatkistdeposito_dim_schatkistdeposito_sqn__dim_schatkistdeposito_sqn___ref_dim_schatkistdeposito_.712d996413' (models/fin/_schema.yml) depends on a node named 'fact_schatkistdeposito' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.unique_fact_verplichtingjournaal_fact_verplichtingjournaal_sqn.ccd5c9677b' (models/fin/_schema.yml) depends on a node named 'fact_verplichtingjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.not_null_fact_verplichtingjournaal_fact_verplichtingjournaal_sqn.08c9026409' (models/fin/_schema.yml) depends on a node named 'fact_verplichtingjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_verplichtingjournaal_dim_boekingscombinatie_sqn__dim_boekingscombinatie_sqn___ref_dim_boekingscombinatie_.52b305c5e9' (models/fin/_schema.yml) depends on a node named 'dim_boekingscombinatie' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_verplichtingjournaal_dim_boekingscombinatie_sqn__dim_boekingscombinatie_sqn___ref_dim_boekingscombinatie_.52b305c5e9' (models/fin/_schema.yml) depends on a node named 'fact_verplichtingjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_verplichtingjournaal_dim_taakveld_sqn__dim_taakveld_sqn___ref_dim_taakveld_.53bb2e9628' (models/fin/_schema.yml) depends on a node named 'dim_taakveld' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_verplichtingjournaal_dim_taakveld_sqn__dim_taakveld_sqn___ref_dim_taakveld_.53bb2e9628' (models/fin/_schema.yml) depends on a node named 'fact_verplichtingjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_verplichtingjournaal_dim_thema_sqn__dim_thema_sqn___ref_fin_conformed_dim_thema_.13685f5275' (models/fin/_schema.yml) depends on a node named 'fact_verplichtingjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_verplichtingjournaal_dim_tactischdoel_sqn__dim_tactischdoel_sqn___ref_fin_conformed_dim_tactischdoel_.392bfbeb74' (models/fin/_schema.yml) depends on a node named 'fact_verplichtingjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_verplichtingjournaal_dim_ambitie_sqn__dim_ambitie_sqn___ref_dim_ambitie_.9467255334' (models/fin/_schema.yml) depends on a node named 'dim_ambitie' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_verplichtingjournaal_dim_ambitie_sqn__dim_ambitie_sqn___ref_dim_ambitie_.9467255334' (models/fin/_schema.yml) depends on a node named 'fact_verplichtingjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_verplichtingjournaal_dim_rvt_3pos_sqn__dim_rvt_3pos_sqn___ref_fin_conformed_dim_rvt_3pos_.de738cacb0' (models/fin/_schema.yml) depends on a node named 'fact_verplichtingjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_verplichtingjournaal_dim_rvt_sqn__dim_rvt_sqn___ref_dim_rvt_.b2d830645a' (models/fin/_schema.yml) depends on a node named 'dim_rvt' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_verplichtingjournaal_dim_rvt_sqn__dim_rvt_sqn___ref_dim_rvt_.b2d830645a' (models/fin/_schema.yml) depends on a node named 'fact_verplichtingjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_verplichtingjournaal_dim_productjaar_sqn__dim_productjaar_sqn___ref_dim_productjaar_.6636b5b422' (models/fin/_schema.yml) depends on a node named 'dim_productjaar' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_verplichtingjournaal_dim_productjaar_sqn__dim_productjaar_sqn___ref_dim_productjaar_.6636b5b422' (models/fin/_schema.yml) depends on a node named 'fact_verplichtingjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_verplichtingjournaal_dim_boekingsperiode_sqn__dim_boekingsperiode_sqn___ref_fin_conformed_dim_boekingsperiode_.29c9d228ab' (models/fin/_schema.yml) depends on a node named 'fact_verplichtingjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_verplichtingjournaal_dim_inkooporder_sqn__dim_inkooporder_sqn___ref_fin_conformed_dim_inkooporder_.94d52f821b' (models/fin/_schema.yml) depends on a node named 'fin_conformed_dim_inkooporder' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_verplichtingjournaal_dim_inkooporder_sqn__dim_inkooporder_sqn___ref_fin_conformed_dim_inkooporder_.94d52f821b' (models/fin/_schema.yml) depends on a node named 'fact_verplichtingjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_verplichtingjournaal_dim_kalender_grootboek_sqn__dim_kalender_sqn___ref_dim_kalender_.7ad7969c2b' (models/fin/_schema.yml) depends on a node named 'fact_verplichtingjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_verplichtingjournaal_dim_leverancier_sqn__dim_leverancier_sqn___ref_fin_conformed_dim_leverancier_.9822583e2b' (models/fin/_schema.yml) depends on a node named 'fact_verplichtingjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_verplichtingjournaal_dim_rapportage_filters_2_sqn__dim_rapportage_filters_2_sqn___ref_fin_conformed_dim_rapportage_filters_2_.92499a2680' (models/fin/_schema.yml) depends on a node named 'fact_verplichtingjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_verplichtingjournaal_dim_rapportage_filters_1_sqn__dim_rapportage_filters_1_sqn___ref_fin_conformed_dim_rapportage_filters_1_.883af72ae5' (models/fin/_schema.yml) depends on a node named 'fact_verplichtingjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_verplichtingjournaal_dim_lb_categorie_sqn__dim_lb_categorie_sqn___ref_dim_lb_categorie_.c2112ca43e' (models/fin/_schema.yml) depends on a node named 'dim_lb_categorie' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Test 'test.dwh.relationships_fact_verplichtingjournaal_dim_lb_categorie_sqn__dim_lb_categorie_sqn___ref_dim_lb_categorie_.c2112ca43e' (models/fin/_schema.yml) depends on a node named 'fact_verplichtingjournaal' in package '' which was not found
# [2025-12-16 00:05:34] [INFO] 00:05:34  [WARNING]: Configuration paths exist in your dbt_project.yml file which do not apply to any resources.
# [2025-12-16 00:05:34] [INFO] There are 2 unused configuration paths:
# [2025-12-16 00:05:34] [INFO] - models.dwh.powerbrowser_dbo_act
# [2025-12-16 00:05:34] [INFO] - seeds.dwh.im_werken
# [2025-12-16 00:05:35] [INFO] 00:05:35  Found 761 models, 21 seeds, 503 data tests, 409 sources, 654 macros
# [2025-12-16 00:05:35] [INFO] 00:05:35
# [2025-12-16 00:05:35] [INFO] 00:05:35  Concurrency: 4 threads (target='dwh_dev')
# [2025-12-16 00:05:35] [INFO] 00:05:35
# [2025-12-16 00:05:36] [INFO] 00:05:36  fabric adapter: No workspace_id provided; skipping snapshot management.
# [2025-12-16 00:05:37] [INFO] 00:05:37  1 of 1 START sql table model im_bab.fna_percelen ............................... [RUN]
# [2025-12-16 00:06:30] [INFO] 00:06:30  1 of 1 OK created sql table model im_bab.fna_percelen .......................... [OK in 52.88s]
# [2025-12-16 00:06:30] [INFO] 00:06:30
# [2025-12-16 00:06:30] [INFO] 00:06:30  Finished running 1 table model in 0 hours 0 minutes and 54.25 seconds (54.25s).
# [2025-12-16 00:06:30] [INFO] 00:06:30
# [2025-12-16 00:06:30] [INFO] 00:06:30  Completed successfully
# [2025-12-16 00:06:30] [INFO] 00:06:30
# [2025-12-16 00:06:30] [INFO] 00:06:30  Done. PASS=1 WARN=0 ERROR=0 SKIP=0 NO-OP=0 TOTAL=1
# [2025-12-16 00:06:30] [INFO] 00:06:30  [WARNING][DeprecationsSummary]: Deprecated functionality
# [2025-12-16 00:06:30] [INFO] Summary of encountered deprecations:
# [2025-12-16 00:06:30] [INFO] - DuplicateYAMLKeysDeprecation: 2 occurrences
# [2025-12-16 00:06:30] [INFO] - MissingArgumentsPropertyInGenericTestDeprecation: 295 occurrences
# [2025-12-16 00:06:30] [INFO] To see all deprecation instances instead of just the first occurrence of each,
# [2025-12-16 00:06:30] [INFO] run command again with the `--show-all-deprecations` flag. You may also need to
# [2025-12-16 00:06:30] [INFO] run with `--no-partial-parse` as some deprecations are only encountered during
# [2025-12-16 00:06:30] [INFO] parsing.
# [2025-12-16 00:06:32] [INFO]
# [2025-12-16 00:06:32] [INFO] ========================================
# [2025-12-16 00:06:32] [INFO] DBT Run Finished
# [2025-12-16 00:06:32] [INFO] Success: True
# [2025-12-16 00:06:32] [INFO] Duration: 71.8s
# [2025-12-16 00:06:32] [INFO] ========================================
